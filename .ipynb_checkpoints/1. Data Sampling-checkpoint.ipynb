# %%
import pandas as pd
import glob
import os

# Install pyarrow by conda prompt: 
# conda install -c conda-forge pyarrow 
# or by pip
#!pip install pyarrow

import pyarrow.parquet as pq
import pyarrow as pa

# %%
#Please define your path here: 
#Reminder: YOUR NOTEBOOK must be in the same place, where the data folder ist. Furthermore you need two sub folders 
# within the data folder: 1) input (place where the csv files are) 2) output (where your parquets will be)
path = r'C:\Users\Davis\Desktop\AAA\data\input'

# %%
#Set year
year = "2017"

# %%
# Data structure: Put folder "data" to the directory, where the 
def load2017data(path,year):

    #get number of files in directory: 
    dirListing = os.listdir(path)
    print("Amount of csv files: ",len(dirListing))

    #initialize divider - helper for the loopings and the naming of the parquet files
    csv_amount = len(dirListing)
    divider_counter = int(csv_amount/50)
    stayover = csv_amount-(divider_counter*50)
    print("Divider: ",50)
    print("Divider counter: ",divider_counter)
    print("Remaining files: ",stayover)

    #Define start and end for loops
    start = 1
    end = 51

    for j in range(1,divider_counter+1):
        #Range is in 50 steps! - Please limit your csv files to 1 mio rows!
        for i in range (start,end):
            all_files = glob.glob(path + "/trips.{}.csv".format(i))
            print(all_files)

            li = []

            for filename in all_files:
                df = pd.read_csv(filename, index_col=None, header=0)
                li.append(df)
        frame = pd.concat(li, axis=0, ignore_index=True)
        frame = frame[frame.iloc[:, 2].str.contains(year) | frame.iloc[:, 3].str.contains("2017")]
        frame = pa.Table.from_pandas(frame)
        pq.write_table(frame, 'data/output/trips_{}.parquet'.format(j))
        print("File saved as: trips_{}.parquet".format(j))
        #caching.clear_cache()

        if j < divider_counter:
            start = end
            end = end +50
            
        # Delete cache
        del frame
        del li
        del df 
        del all_files

    start = end 
    end = end+ stayover-1
    print()
    print("New start: ",start)
    print("New end: ",end)
    print()

    # Add all files, which are remaning outside of the counter
    for i in range(start,end):
        all_files = glob.glob(path + "/trips.{}.csv".format(i))
        print(all_files)

        li = []

        for filename in all_files:
            df = pd.read_csv(filename, index_col=None, header=0)
            li.append(df)
    frame = pd.concat(li, axis=0, ignore_index=True)
    frame = frame[frame.iloc[:, 2].str.contains(year) | frame.iloc[:, 3].str.contains("2017")]
    frame = pa.Table.from_pandas(frame)
    pq.write_table(frame, 'data/output/trips_{}.parquet'.format(divider_counter+1))
    print("File saved as: trips_{}.parquet".format(divider_counter+1))
    
    # Delete cache
    del frame
    del li
    del df 
    del all_files

    print()
    print("Finished!")

# %%
#Run function
load2017data(path,year)
# Out:
# Amount of csv files:  85
# Divider:  50
# Divider counter:  1
# Remaining files:  35
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.1.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.2.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.3.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.4.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.5.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.6.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.7.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.8.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.9.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.10.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.11.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.12.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.13.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.14.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.15.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.16.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.17.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.18.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.19.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.20.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.21.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.22.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.23.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.24.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.25.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.26.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.27.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.28.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.29.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.30.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.31.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.32.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.33.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.34.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.35.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.36.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.37.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.38.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.39.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.40.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.41.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.42.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.43.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.44.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.45.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.46.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.47.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.48.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.49.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.50.csv']
# File saved as: trips_1.parquet
#
# New start:  51
# New end:  85
#
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.51.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.52.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.53.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.54.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.55.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.56.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.57.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.58.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.59.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.60.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.61.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.62.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.63.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.64.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.65.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.66.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.67.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.68.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.69.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.70.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.71.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.72.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.73.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.74.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.75.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.76.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.77.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.78.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.79.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.80.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.81.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.82.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.83.csv']
# ['C:\\Users\\Davis\\Desktop\\AAA\\data\\input/trips.84.csv']
# File saved as: trips_2.parquet
#
# Finished!

# %% [markdown]
# # Reading csv files

# %%
#Read files
path = r'C:\Users\Davis\Desktop\AAA\data\output\*.parquet'
files = glob.glob(path)
files.sort()
df = pd.concat([pd.read_parquet(fp) for fp in files])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-227666e5cd14> in <module>
#       1 #Read files
#       2 path = r'C:\Users\Davis\Desktop\AAA\data\output\*.parquet'
# ----> 3 files = glob.glob(path)
#       4 files.sort()
#       5 df = pd.concat([pd.read_parquet(fp) for fp in files])
#
# NameError: name 'glob' is not defined

# %%
df.info(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1361 entries, 0 to 399
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Trip ID                     1361 non-null   object
#  1   Taxi ID                     1361 non-null   object
#  2   Trip Start Timestamp        1361 non-null   object
#  3   Trip End Timestamp          1361 non-null   object
#  4   Trip Seconds                1361 non-null   float64
#  5   Trip Miles                  1361 non-null   float64
#  6   Pickup Census Tract         863 non-null    float64
#  7   Dropoff Census Tract        862 non-null    float64
#  8   Pickup Community Area       1226 non-null   float64
#  9   Dropoff Community Area      1192 non-null   float64
#  10  Fare                        1361 non-null   float64
#  11  Tips                        1361 non-null   float64
#  12  Tolls                       1361 non-null   float64
#  13  Extras                      1361 non-null   float64
#  14  Trip Total                  1361 non-null   float64
#  15  Payment Type                1361 non-null   object
#  16  Company                     1361 non-null   object
#  17  Pickup Centroid Latitude    1226 non-null   float64
#  18  Pickup Centroid Longitude   1226 non-null   float64
#  19  Pickup Centroid Location    1226 non-null   object
#  20  Dropoff Centroid Latitude   1194 non-null   float64
#  21  Dropoff Centroid Longitude  1194 non-null   float64
#  22  Dropoff Centroid  Location  1194 non-null   object
# dtypes: float64(15), object(8)
# memory usage: 255.2+ KB

# %% [markdown]
# ## Sampling

# %%
import pandas as pd
import pyarrow.parquet as pq
import pyarrow as pa
import glob

# %%
df_trips = pd.read_csv(r"C:\Users\Davis\Downloads\trips.csv")

# %%
cols_dropped = df_trips.dropna(inplace=False)

# %%
print("The original frame has",len(df_trips),"rows")
print(len(df_trips)-len(cols_dropped),"null values within the stream")
# Out:
# The original frame has 24988003 rows
# 12344331 null values within the stream

# %%
# Sampling 
def sampleFile(sample_size,df):
    df_new = df.sample(frac = (sample_size/100))
    return df_new

# %%
df_sample = sampleFile(20,cols_dropped)

# %%
df_sample.head()
# Out:
#                                            Trip ID  \
# 15971142  65f93c35817734e3299be976d4f3b376bdd91416
# 167943    7a592eba4fe74de911db4b33878eab697730ddc2
# 14807345  25e63440cd1d3596401101ffde933ec7318acfe3
# 3157769   a578a81d70af56cbbe627df7acc970cfd955333e
# 24803407  5499349d0b89bf47f44990d6380b038a48c56bc1
#
#                                                     Taxi ID  \
# 15971142  561fbb8af15689fe33fb11b96905cfb95d11ac44700c1a...
# 167943    1025e3aec9a251a432a6bca2bbe7a95bc032b369fd5be1...
# 14807345  e81aeae39261dd72f248f92204fd28e77269f6bcf5d5c8...
# 3157769   bb870d48c69eb329b88cb373037a1ee2d1c43f2d67a4b5...
# 24803407  f86da6500edc020c8e0fef6be42bd747e0c7316b59e32f...
#
#             Trip Start Timestamp      Trip End Timestamp  Trip Seconds  \
# 15971142  08/12/2017 06:45:00 PM  08/12/2017 07:15:00 PM        1965.0
# 167943    01/04/2017 12:30:00 PM  01/04/2017 12:45:00 PM         610.0
# 14807345  07/26/2017 07:45:00 PM  07/26/2017 07:45:00 PM         298.0
# 3157769   02/18/2017 02:00:00 PM  02/18/2017 02:15:00 PM         805.0
# 24803407  12/27/2017 06:00:00 PM  12/27/2017 06:00:00 PM         388.0
#
#           Trip Miles  Pickup Census Tract  Dropoff Census Tract  \
# 15971142       18.40         1.703198e+10          1.703108e+10
# 167943          1.55         1.703108e+10          1.703184e+10
# 14807345        0.99         1.703184e+10          1.703108e+10
# 3157769         1.46         1.703132e+10          1.703108e+10
# 24803407        0.70         1.703184e+10          1.703108e+10
#
#           Pickup Community Area  Dropoff Community Area  ...  Extras  \
# 15971142                   76.0                     8.0  ...     6.0
# 167943                      8.0                     8.0  ...     0.0
# 14807345                   32.0                     8.0  ...     1.0
# 3157769                    32.0                     8.0  ...     1.0
# 24803407                   32.0                     8.0  ...     0.0
#
#           Trip Total  Payment Type                    Company  \
# 15971142       52.00          Cash  Chicago Carriage Cab Corp
# 167943          8.00          Cash  Chicago Carriage Cab Corp
# 14807345       11.50   Credit Card               City Service
# 3157769         9.75          Cash  Nova Taxi Affiliation Llc
# 24803407        8.25   Credit Card               City Service
#
#           Pickup Centroid Latitude Pickup Centroid Longitude  \
# 15971142                 41.979071                -87.903040
# 167943                   41.890922                -87.618868
# 14807345                 41.880994                -87.632746
# 3157769                  41.877406                -87.621972
# 24803407                 41.880994                -87.632746
#
#                       Pickup Centroid Location  Dropoff Centroid Latitude  \
# 15971142  POINT (-87.9030396611 41.9790708201)                  41.892508
# 167943    POINT (-87.6188683546 41.8909220259)                  41.904935
# 14807345  POINT (-87.6327464887 41.8809944707)                  41.892042
# 3157769   POINT (-87.6219716519 41.8774061234)                  41.898332
# 24803407  POINT (-87.6327464887 41.8809944707)                  41.892508
#
#           Dropoff Centroid Longitude            Dropoff Centroid  Location
# 15971142                  -87.626215  POINT (-87.6262149064 41.8925077809)
# 167943                    -87.649907  POINT (-87.6499072264 41.9049353016)
# 14807345                  -87.631864  POINT (-87.6318639497 41.8920421365)
# 3157769                   -87.620763  POINT (-87.6207628651 41.8983317935)
# 24803407                  -87.626215  POINT (-87.6262149064 41.8925077809)
#
# [5 rows x 23 columns]

# %%
df_sample.index
# Out:
# Int64Index([15971142,   167943, 14807345,  3157769, 24803407, 18992750,
#              9828117, 15539240,  4257031,  1117004,
#             ...
#             17535169,  6692788, 15347754,  8507069,  1335934, 10102181,
#              9731064, 11889045, 15262000, 22504342],
#            dtype='int64', length=2528734)

# %%
#Write parquet file
frame = pa.Table.from_pandas(df_sample)
pq.write_table(frame, 'df_trips_sample_nullsdropped.parquet')

# %%
#Reading parquet files: 
path = r'df_trips_sample.parquet'
files = glob.glob(path)
files.sort()
df = pd.concat([pd.read_parquet(fp) for fp in files])

# %%
df.head()
# Out:
#                                            Trip ID  \
# 24357273  06bd2062d4da87baf5e6c60645adf4018ff5a1f5
# 23594347  636eae5de0817802f3befa320b660551e245f0af
# 14171117  a7c5166b39b3eb990f6aa84e43b5064f43c3cc79
# 13794016  25c415d2f38913f8a5c789e7a7002a12e1a13e75
# 12304106  0a67be58ffe7778950205e6dc105e4a57ba58192
#
#                                                     Taxi ID  \
# 24357273  3c0dce2f97f9acc211c5a886cff53caf700e8ba821ae26...
# 23594347  dcfc039460c91afe6099789b8f3b8ef854815c6345723e...
# 14171117  ca85563c7c46f07258ff388e8a43a1502115d1824dd00b...
# 13794016  f2701208e420d05c34de4131a15848a786b13422bf5865...
# 12304106  c81a672f30763423ddc7abac2b2e20a2f1ea045088ef77...
#
#             Trip Start Timestamp      Trip End Timestamp  Trip Seconds  \
# 24357273  12/18/2017 11:15:00 AM  12/18/2017 12:00:00 PM        3000.0
# 23594347  12/06/2017 08:15:00 PM  12/06/2017 08:30:00 PM         420.0
# 14171117  07/17/2017 11:30:00 PM  07/17/2017 11:45:00 PM         900.0
# 13794016  07/12/2017 05:15:00 PM  07/12/2017 06:15:00 PM        3420.0
# 12304106  06/20/2017 10:45:00 AM  06/20/2017 10:45:00 AM          19.0
#
#           Trip Miles  Pickup Census Tract  Dropoff Census Tract  \
# 24357273       11.20                  NaN                   NaN
# 23594347        1.10         1.703184e+10          1.703108e+10
# 14171117        5.66                  NaN                   NaN
# 13794016       21.00         1.703184e+10          1.703198e+10
# 12304106        0.00         1.703108e+10          1.703108e+10
#
#           Pickup Community Area  Dropoff Community Area  ...  Extras  \
# 24357273                   60.0                     3.0  ...     0.0
# 23594347                   32.0                     8.0  ...     0.0
# 14171117                    NaN                     NaN  ...     1.0
# 13794016                   33.0                    76.0  ...     1.5
# 12304106                    8.0                     8.0  ...     0.0
#
#           Trip Total  Payment Type                          Company  \
# 24357273       37.50          Cash             Chicago Independents
# 23594347        8.75   Credit Card        Taxi Affiliation Services
# 14171117       18.25          Cash  Taxi Affiliation Service Yellow
# 13794016       53.00          Cash              Top Cab Affiliation
# 12304106        3.25          Cash                     Checker Taxi
#
#           Pickup Centroid Latitude Pickup Centroid Longitude  \
# 24357273                 41.836150                -87.648788
# 23594347                 41.880994                -87.632746
# 14171117                       NaN                       NaN
# 13794016                 41.849247                -87.624135
# 12304106                 41.892508                -87.626215
#
#                           Pickup Centroid Location  Dropoff Centroid Latitude  \
# 24357273      POINT (-87.6487879519 41.8361501547)                  41.965812
# 23594347      POINT (-87.6327464887 41.8809944707)                  41.892073
# 14171117                                      None                        NaN
# 13794016  POINT (-87.6241352979 41.84924675450001)                  41.979071
# 12304106      POINT (-87.6262149064 41.8925077809)                  41.892508
#
#           Dropoff Centroid Longitude            Dropoff Centroid  Location
# 24357273                  -87.655879    POINT (-87.6558787862 41.96581197)
# 23594347                  -87.628874  POINT (-87.6288741572 41.8920726347)
# 14171117                         NaN                                  None
# 13794016                  -87.903040  POINT (-87.9030396611 41.9790708201)
# 12304106                  -87.626215  POINT (-87.6262149064 41.8925077809)
#
# [5 rows x 23 columns]
