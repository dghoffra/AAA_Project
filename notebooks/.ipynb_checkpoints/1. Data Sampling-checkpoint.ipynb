# %%
#Imports
import pandas as pd
import pyarrow.parquet as pq
import pyarrow as pa
import glob
from datetime import date

# %%
#Read csv file (change directory in your path or renamve csv to trips)
df_trips = pd.read_csv("../data/input/trips.csv")

# %%
cols_dropped = df_trips.dropna(inplace=False)

# %%
print("The original frame has",len(df_trips),"rows")
print(len(df_trips)-len(cols_dropped),"null values within the stream")
print("Remember: There are also null values in columns just because of privacy reasons - Actually we don't should drop them")
# Out:
# The original frame has 1000000 rows
# 999993 null values within the stream
# Remember: There are also null values in columns just because of privacy reasons - Actually we don't should drop them

# %%
#Sampling function
def sampleFile(sample_size,df):
    df_new = df.sample(frac = (sample_size/100))
    return df_new

# %%
#Sample df to 20% of original frame 
df_sample = sampleFile(20,df_trips)

# %%
df_sample.head()
# Out:
#                                          Trip ID  \
# 528120  b89534655e07727455fed80508fbfd0626f9b15e
# 527378  169a0a030a1f27b69415e2496e1e01a05fc77814
# 158378  1019c6de7030997703bdcc58f537bc450c297d5b
# 299790  8dd539b89714db74be865ff56525ddf067cb1d6f
# 631428  9bc81cd81809b503430494a083c2fb2c5fc325f9
#
#                                                   Taxi ID  \
# 528120  800514cef2fedac7b982b2ba503909e4d30295b46723c3...
# 527378  dd7341ff0099d3c6e4f72299b69cd3d8fccb783a22b32c...
# 158378  aa4c3beb61a579d4f214d3f92395a4f7bc7245a2cb21eb...
# 299790  4324dfe74f160fb8c591887de768a75a7f87b58c3ff790...
# 631428  de9289a1fce135051f6e9206044f8211c86a1a6acd68d4...
#
#           Trip Start Timestamp      Trip End Timestamp  Trip Seconds  \
# 528120  06/25/2013 11:45:00 AM  06/25/2013 12:00:00 PM         900.0
# 527378  06/08/2013 07:00:00 PM  06/08/2013 07:00:00 PM         420.0
# 158378  01/30/2013 01:00:00 PM  01/30/2013 01:00:00 PM         300.0
# 299790  03/29/2013 04:00:00 PM  03/29/2013 04:15:00 PM         600.0
# 631428  04/06/2013 01:00:00 AM  04/06/2013 01:00:00 AM         420.0
#
#         Trip Miles  Pickup Census Tract  Dropoff Census Tract  \
# 528120         3.3                  NaN                   NaN
# 527378         1.2                  NaN                   NaN
# 158378         0.6                  NaN                   NaN
# 299790         2.6                  NaN                   NaN
# 631428         2.0                  NaN                   NaN
#
#         Pickup Community Area  Dropoff Community Area  ...  Extras  \
# 528120                    NaN                     NaN  ...     0.0
# 527378                    NaN                     NaN  ...     1.0
# 158378                    NaN                     NaN  ...     0.0
# 299790                    NaN                     NaN  ...     0.0
# 631428                    NaN                     NaN  ...     1.0
#
#         Trip Total  Payment Type  Company  Pickup Centroid Latitude  \
# 528120       11.45          Cash      NaN                       NaN
# 527378        7.45          Cash      NaN                       NaN
# 158378        5.05          Cash      NaN                       NaN
# 299790        9.25          Cash      NaN                       NaN
# 631428        8.65          Cash      NaN                       NaN
#
#        Pickup Centroid Longitude Pickup Centroid Location  \
# 528120                       NaN                      NaN
# 527378                       NaN                      NaN
# 158378                       NaN                      NaN
# 299790                       NaN                      NaN
# 631428                       NaN                      NaN
#
#         Dropoff Centroid Latitude  Dropoff Centroid Longitude  \
# 528120                        NaN                         NaN
# 527378                        NaN                         NaN
# 158378                        NaN                         NaN
# 299790                        NaN                         NaN
# 631428                        NaN                         NaN
#
#        Dropoff Centroid  Location
# 528120                        NaN
# 527378                        NaN
# 158378                        NaN
# 299790                        NaN
# 631428                        NaN
#
# [5 rows x 23 columns]

# %%
df_sample.index
# Out:
# Int64Index([528120, 527378, 158378, 299790, 631428,  80480,  31639, 968708,
#              87332,  46262,
#             ...
#             403575, 160543, 618675, 588187, 399632, 616318, 948807, 879793,
#             830778, 739992],
#            dtype='int64', length=200000)

# %%
#Write parquet of sample frame
frame = pa.Table.from_pandas(df_sample)
pq.write_table(frame, '../data/df_sample_{}.parquet'.format(date.today().strftime("%d_%m_%Y")))
