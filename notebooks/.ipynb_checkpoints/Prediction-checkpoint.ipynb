# %%
#get notebook runtime
from timeit import default_timer as timer
start = timer()

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Characteristics

# %% [markdown]
# Let's recall the characteristics of our dataset:

# %%
#get notebook runtime
start = timer()

# %%
df = pd.read_parquet("../data/df_cleaned_18_06_2021.parquet")

# %%
df.shape
# Out:
# (4328648, 33)

# %%
df.head()
# Out:
#                                            Trip ID  \
# 10019694  0186acc0c8d50828e6dc5c9072ace58101e3e1b1
# 7792802   7d0830d9dbbd03a9e1b5d1d99cd41d99d7b8fb90
# 7493958   171ea5e4956fe55a58f9ec3be65238af8b79c4c2
# 5984763   a6da0037deae54685ba3a1a559ae6a33b9028bd9
# 4498023   58bc23a32b790e568d3c50bc38e5dd473cbc9fcf
#
#                                                     Taxi ID  \
# 10019694  9a38858dc2ace73a20f89a976154131a733daf1f11e8d6...
# 7792802   b4d59da1d7b8c002094752251906d9a3bcc6c7ea71a15f...
# 7493958   38c32bfda2f77c2a57f33a9e3fcf7edb8e996f59bc2254...
# 5984763   e2c349c7cbb608d552aa0b5814031943f13641ef9e50d8...
# 4498023   cbdd490649df25aa771979bed8930b199d27a990ccdb42...
#
#          Trip Start Timestamp  Trip End Timestamp  Trip Seconds  Trip Miles  \
# 10019694  2017-05-20 23:45:00 2017-05-20 23:45:00         360.0        1.30
# 7792802   2017-04-21 22:15:00 2017-04-21 22:15:00         300.0        0.40
# 7493958   2017-04-18 10:30:00 2017-04-18 10:45:00         379.0        1.00
# 5984763   2017-03-28 16:15:00 2017-03-28 16:15:00         317.0        0.96
# 4498023   2017-03-09 14:30:00 2017-03-09 14:30:00         360.0        1.00
#
#           Pickup Census Tract  Dropoff Census Tract  Pickup Community Area  \
# 10019694         1.703106e+10          1.703107e+10                    6.0
# 7792802          1.703108e+10          1.703108e+10                    8.0
# 7493958          1.703184e+10          1.703128e+10                   32.0
# 5984763          1.703108e+10          1.703108e+10                    8.0
# 4498023          1.703128e+10          1.703184e+10                   28.0
#
#           Dropoff Community Area  ...            PU_H3            DO_H3  \
# 10019694                     7.0  ...  872c2118bffffff  872c2118affffff
# 7792802                      8.0  ...  872c2119dffffff  872c2119dffffff
# 7493958                     28.0  ...  872c21191ffffff  872c2119cffffff
# 5984763                      8.0  ...  872c2119cffffff  872c2119cffffff
# 4498023                     32.0  ...  872c2119cffffff  872c21191ffffff
#
#           PU_MONTH_NAME  PU_WEEKDAY_NAME  PU_YEAR PU_MONTH PU_WEEKDAY  \
# 10019694            May         Saturday     2017        5          5
# 7792802           April           Friday     2017        4          4
# 7493958           April          Tuesday     2017        4          1
# 5984763           March          Tuesday     2017        3          1
# 4498023           March         Thursday     2017        3          3
#
#           PU_HOUR  PU_HOUR_OF_WEEK PU_FOUR_HOURLY
# 10019694       24              144            5/5
# 7792802        23              119            5/5
# 7493958        11               35            3/5
# 5984763        17               41            4/5
# 4498023        15               87            3/5
#
# [5 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# Trip ID                             0
# Taxi ID                          1477
# Trip Start Timestamp                0
# Trip End Timestamp                  0
# Trip Seconds                        0
# Trip Miles                          0
# Pickup Census Tract           1303676
# Dropoff Census Tract          1316214
# Pickup Community Area          309000
# Dropoff Community Area         392386
# Fare                                0
# Tips                                0
# Tolls                         1138339
# Extras                              0
# Trip Total                          0
# Payment Type                        0
# Company                             0
# Pickup Centroid Latitude       308810
# Pickup Centroid Longitude      308810
# Pickup Centroid Location       308810
# Dropoff Centroid Latitude      379954
# Dropoff Centroid Longitude     379954
# Dropoff Centroid  Location     379954
# PU_H3                          308810
# DO_H3                          379954
# PU_MONTH_NAME                       0
# PU_WEEKDAY_NAME                     0
# PU_YEAR                             0
# PU_MONTH                            0
# PU_WEEKDAY                          0
# PU_HOUR                             0
# PU_HOUR_OF_WEEK                     0
# PU_FOUR_HOURLY                      0
# dtype: int64

# %%
df_pairplot = df[:100]

# %%
#sns.pairplot(df_pairplot, hue='PU_H3')

# %% [markdown]
# Nun schauen wir uns explizit die Korrelationen der Variablen an. Wie ebenfalls im vorigen Plot zu observieren, sehen wir hier, dass die Variablen zum Teil stark positiv sowie negativ korrelieren.

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %% [markdown]
# Nun schauen wir uns die Verteilung unserer Zielvariablen taxi_demand (auf stündlicher basis) genauer an. Es ist zu erkennen, dass Samstags und Sonntags wesentlich häufiger früh am morgen das Taxi genutzt wird, als unter der Woche.

# %%
sns.displot(df,x='PU_HOUR', hue='PU_WEEKDAY', bins=24)

# %% [markdown]
# ## 4. SVM

# %% [markdown]
# ### Data Preparation for 4.1 SVM and 4.2 NN

# %% [markdown]
# Let's start with a reuseable function to get a dataframe of the selected temporal and spatial resolution. To obtain robust values for the predictors, we use the median.

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# %%
#TODO: Felix input for feature selection

# %%
def get_data(df, temp_resolution):
    
    #df_new = df.groupby(pd.Grouper(key="Trip Start Timestamp", freq=temp_resolution)).median()
    #df_new['count'] = df.groupby(pd.Grouper(key="Trip Start Timestamp", freq=temp_resolution))['Trip Start Timestamp'].count()
    #df_new.dropna(inplace=True)
    
    
    #group by temporal and spacial resolutions
    df_new = df.groupby(['PU_H3', pd.Grouper(key="Trip Start Timestamp", freq=temp_resolution)]).median()#create df based on temporal and spacial specifications
    df_new['count'] = df.groupby(['PU_H3', pd.Grouper(key="Trip Start Timestamp", freq=temp_resolution)]).size()#add demand for each unit of analysis; note that the frame is grouped by two features
    df_new.dropna(inplace=True)
    print("Dataframe after applying temporal and spacial specifications: ")#debug information
    print("Shape: ",df_new.shape)
    print("Demand description for temporal/spatial units (e.g. 2017-01-01 09:00, 8826641915fffff): ")
    print(df_new['count'].describe())


    
    #select target and predictors
    y = df_new['count']
    X = df_new.drop('count', axis=1)
    print('Debug Information')
    print('-------------------------------')
    print("Shape Featureset/Target: ", X.shape, y.shape)
    
    #split data
    x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.6, random_state=38)
    
    #scale data
    scaler = StandardScaler()
    scaler.fit(x_train) #fit scaler
    X_train_scaled = scaler.transform(x_train) #apply to both, train and test set
    X_test_scaled = scaler.transform(x_test)
    print("Shape after scaling trainingset: ", X_train_scaled.shape, y_train.shape)
    print("Shape after scaling testset: ", X_test_scaled.shape, y_test.shape)
    
    #select best features
    selector = SelectKBest(f_classif, k=5)
    selector.fit(X_train_scaled, y_train)
    cols = selector.get_support(indices=True)#get selected columns
    X_train_new = X_train_scaled[:,cols]#apply to train&test set
    X_test_new = X_test_scaled[:,cols]
    print("X_Train:", X_train_new.shape, "X_Test:", X_test_new.shape)
    
    return X_train_new, X_test_new, y_train, y_test

# %% [markdown]
# ### 4.1.1 SVM Prediction

# %% [markdown]
# First, we define a training method and to use it for training our models. Consequently, we will start with simple models and improve them for better performance.

# %%
#function to train and evaluate our models later on
import sklearn.metrics as metrics
import numpy as np

def train(model, model_name, x_train, x_test, y_train, y_test, element):
    
    print()
    print(model_name, element) # Printing model name
    print('-------------------------------')
    model.fit(x_train,y_train) # fitting the defined model
    pred = model.predict(x_test) # predicting our data

    acc = metrics.r2_score(y_test, pred) #Checking R2_Score
    print('R2_Score',acc)

    met = np.sqrt(metrics.mean_squared_error(y_test, pred)) #Calculating RMSE
    print('RMSE : ', met) 

    var = (metrics.explained_variance_score(y_test, pred)) #Calculating explained_variance_score
    print('Explained_Variance : ', var)

    error = (metrics.max_error(y_test, pred)) #Calculating Max_Error
    print('Max_Error : ', error)
    
    err = metrics.mean_absolute_error(y_test, pred) #Calculating mean_absolute_error
    print("Mean Absolute Error", err)
    print()
    print()
    
    return model_name + '($R^2={:.3f}$)'.format(acc), np.array(y_test), pred

# %%
#select data to start with, we use a daily level for our inital modeling 

X_train_new, X_test_new, y_train, y_test = get_data(df, temp_resolution="24H")
# Out:
# Dataframe after applying temporal and spacial specifications:
# Shape:  (184692, 20)
# Demand description for temporal/spatial units (e.g. 2017-01-01 09:00, 8826641915fffff):
# count    184692.000000
# mean         18.398388
# std          29.547691
# min           1.000000
# 25%           2.000000
# 50%           6.000000
# 75%          22.000000
# max         320.000000
# Name: count, dtype: float64
# Debug Information
# -------------------------------
# Shape Featureset/Target:  (184692, 19) (184692,)
# Shape after scaling trainingset:  (110815, 19) (110815,)
# Shape after scaling testset:  (73877, 19) (73877,)
# X_Train: (110815, 5) X_Test: (73877, 5)

# %%
#Start without a Kernel
results=[] #save results-tuple for visualization
model_svr = SVR()
results.append(train(model_svr, "SVR", X_train_new, X_test_new,
                     y_train, y_test, "24H" ))
# Out:
# SVR 1H
# -------------------------------

# %%
#Make more complex
model_svr2 = SVR(kernel='linear')
results.append(train(model_svr2, "SVR_Linear", X_train_new, X_test_new,
                     y_train, y_test, "24H"))

# %%
#TODO Hyperparameter Tuning

# %% [markdown]
# ### 4.1.2 Model Evaluation (Visually)

# %% [markdown]
# In this section, we will examine the performance of our models more closely. For this, we will look at the visual characteristics of our predictions.

# %%
# Bessere Visualisierung einbauen

# %%
#Create a plot comparing multiple learners
def plot(results):
    # Using subplots to display the results on the same X axis
    fig, plts = plt.subplots(nrows=len(results), figsize=(8, 8))
    fig.canvas.set_window_title('Predicting Chicago')

    # Show each element in the plots returned from plt.subplots()
    for subplot, (title, y, y_pred) in zip(plts, results):
        # Configure each subplot to have no tick marks
        # (these are meaningless for the sample dataset)
        subplot.set_xticklabels(())
        subplot.set_yticklabels(())

        # Label the vertical axis
        subplot.set_ylabel('Taxi Demand')
        subplot.set_xlabel('Time')

        # Set the title for the subplot
        subplot.set_title(title)

        # Plot the actual data and the prediction
        subplot.plot(y, 'b', label='actual')
        subplot.plot(y_pred, 'r', label='predicted')
        
        # Shade the area between the predicted and the actual values
        subplot.fill_between(
            # Generate X values [0, 1, 2, ..., len(y)-2, len(y)-1]
            np.arange(0, len(y), 1),
            y,
            y_pred,
            color='r',
            alpha=0.2
        )

        # Mark the extent of the training data
        subplot.axvline(len(y) // 2, linestyle='--', color='0', alpha=0.2)

        # Include a legend in each subplot
        subplot.legend()

    # Let matplotlib handle the subplot layout
    fig.tight_layout()
    plt.show()
    plt.savefig('plot.png')
    plt.close()

# %%
plot(results)

# %% [markdown]
# ### 4.1.3 Variation of Temporal and Spatial Resolution

# %% [markdown]
# In this section, we aim to explore the performance of our best model based on a variation of termporal and spatial resolutions.

# %%
#TODO: Add Spatial Resolution

# %%
#generate datasets - temporal dimension
temporal_resolution_levels = ['24H', '6H', '2H', '1H']

results = []

for element in temporal_resolution_levels:
    model = SVR(kernel='linear')
    X_train_new, X_test_new, y_train, y_test = get_data(df, element)
    results.append(train(model, "SVR_Linear", X_train_new, X_test_new,
                         y_train, y_test, element))

end = timer()
print()
print("Total Notebook Runtime (s): ", end - start)
# Out:
# Debug Information
# -------------------------------
# Shape Featureset/Target:  (334, 19) (334,)
# Shape after scaling trainingset:  (200, 19) (200,)
# Shape after scaling testset:  (134, 19) (134,)
# X_Train: (200, 5) X_Test: (134, 5)
#
# SVR_Linear 24H
# -------------------------------
# R2_Score 0.13031826902628396
# RMSE :  2112.859044372903
# Explained_Variance :  0.13554777824283049
# Max_Error :  6112.147875861725
# Mean Absolute Error 1761.087052083442
#
#
# Debug Information
# -------------------------------
# Shape Featureset/Target:  (1336, 19) (1336,)
# Shape after scaling trainingset:  (801, 19) (801,)
# Shape after scaling testset:  (535, 19) (535,)
# X_Train: (801, 5) X_Test: (535, 5)
#
# SVR_Linear 6H
# -------------------------------
# R2_Score 0.6671077018805995
# RMSE :  921.0311563241523
# Explained_Variance :  0.6673190137385241
# Max_Error :  3388.1471819477038
# Mean Absolute Error 754.2306367483491
#
#
# Debug Information
# -------------------------------
# Shape Featureset/Target:  (4008, 19) (4008,)
# Shape after scaling trainingset:  (2404, 19) (2404,)
# Shape after scaling testset:  (1604, 19) (1604,)
# X_Train: (2404, 5) X_Test: (1604, 5)
#
# SVR_Linear 2H
# -------------------------------
# R2_Score 0.5665135902458533
# RMSE :  392.8172848981964
# Explained_Variance :  0.5754805967658527
# Max_Error :  2416.9833266698706
# Mean Absolute Error 290.04144611438704
#
#
# Debug Information
# -------------------------------
# Shape Featureset/Target:  (8013, 19) (8013,)
# Shape after scaling trainingset:  (4807, 19) (4807,)
# Shape after scaling testset:  (3206, 19) (3206,)
# X_Train: (4807, 5) X_Test: (3206, 5)
#
# SVR_Linear 1H
# -------------------------------
# R2_Score 0.5158911821314085
# RMSE :  209.3623294273839
# Explained_Variance :  0.5252548301028601
# Max_Error :  1875.4394126267152
# Mean Absolute Error 148.00217770454316
#
#
#
# Total Notebook Runtime:  262.433854848

# %%
#77community areas
#866 census tracts (population between 0 - 10000)
#resolution 0-15, with 0 beeing the

# %%
import h3

resolution = 1
#calculate new H3 based on specified resolution
df["PU_H3"] = df.apply(lambda x: h3.geo_to_h3(x["Pickup Centroid Latitude"], x['Pickup Centroid Longitude'],8),axis=1)
df["PU_H3"] = df["PU_H3"].replace("0",np.nan)

# %%
df_new = df.groupby(['PU_H3', pd.Grouper(key="Trip Start Timestamp", freq="24H")]).median()

# %%
df_new
# Out:
#                                       Trip Seconds  Trip Miles  \
# PU_H3           Trip Start Timestamp
# 8826641915fffff 2017-01-30                  2396.0        23.8
#                 2017-01-31                  2460.0        19.0
#                 2017-02-03                  2513.0        12.2
#                 2017-03-07                  1607.0         7.2
#                 2017-03-12                   213.0         0.0
# ...                                            ...         ...
# 88275936d5fffff 2017-11-26                   273.0         1.7
#                 2017-11-27                  1009.0         5.2
#                 2017-11-28                   789.0         3.8
#                 2017-11-29                  1186.0         8.6
#                 2017-11-30                  2520.0         0.3
#
#                                       Pickup Census Tract  \
# PU_H3           Trip Start Timestamp
# 8826641915fffff 2017-01-30                            NaN
#                 2017-01-31                            NaN
#                 2017-02-03                            NaN
#                 2017-03-07                            NaN
#                 2017-03-12                            NaN
# ...                                                   ...
# 88275936d5fffff 2017-11-26                            NaN
#                 2017-11-27                            NaN
#                 2017-11-28                            NaN
#                 2017-11-29                            NaN
#                 2017-11-30                            NaN
#
#                                       Dropoff Census Tract  \
# PU_H3           Trip Start Timestamp
# 8826641915fffff 2017-01-30                             NaN
#                 2017-01-31                             NaN
#                 2017-02-03                             NaN
#                 2017-03-07                             NaN
#                 2017-03-12                             NaN
# ...                                                    ...
# 88275936d5fffff 2017-11-26                             NaN
#                 2017-11-27                             NaN
#                 2017-11-28                             NaN
#                 2017-11-29                             NaN
#                 2017-11-30                             NaN
#
#                                       Pickup Community Area  \
# PU_H3           Trip Start Timestamp
# 8826641915fffff 2017-01-30                             55.0
#                 2017-01-31                             55.0
#                 2017-02-03                             55.0
#                 2017-03-07                             55.0
#                 2017-03-12                             55.0
# ...                                                     ...
# 88275936d5fffff 2017-11-26                              9.0
#                 2017-11-27                              9.0
#                 2017-11-28                              9.0
#                 2017-11-29                              9.0
#                 2017-11-30                              9.0
#
#                                       Dropoff Community Area   Fare  Tips  \
# PU_H3           Trip Start Timestamp
# 8826641915fffff 2017-01-30                              23.0  58.25  0.00
#                 2017-01-31                              32.0  48.00  0.00
#                 2017-02-03                              61.0  38.25  0.00
#                 2017-03-07                              43.0  22.00  0.00
#                 2017-03-12                              55.0   3.25  0.00
# ...                                                      ...    ...   ...
# 88275936d5fffff 2017-11-26                              10.0   7.25  0.00
#                 2017-11-27                              17.0  16.50  0.00
#                 2017-11-28                              76.0  13.25  0.00
#                 2017-11-29                              76.0  24.25  4.85
#                 2017-11-30                              76.0  19.00  0.00
#
#                                       Tolls  Extras  Trip Total  \
# PU_H3           Trip Start Timestamp
# 8826641915fffff 2017-01-30              NaN     0.0       58.25
#                 2017-01-31              0.0     0.0       48.00
#                 2017-02-03              NaN     0.0       38.25
#                 2017-03-07              NaN     0.0       22.00
#                 2017-03-12              NaN    27.0       30.25
# ...                                     ...     ...         ...
# 88275936d5fffff 2017-11-26              NaN     1.0        8.25
#                 2017-11-27              NaN     0.0       16.50
#                 2017-11-28              NaN     0.0       13.25
#                 2017-11-29              NaN     0.0       29.10
#                 2017-11-30              0.0     0.0       19.00
#
#                                       Pickup Centroid Latitude  \
# PU_H3           Trip Start Timestamp
# 8826641915fffff 2017-01-30                           41.663671
#                 2017-01-31                           41.663671
#                 2017-02-03                           41.663671
#                 2017-03-07                           41.663671
#                 2017-03-12                           41.663671
# ...                                                        ...
# 88275936d5fffff 2017-11-26                           42.007613
#                 2017-11-27                           42.007613
#                 2017-11-28                           42.007613
#                 2017-11-29                           42.007613
#                 2017-11-30                           42.007613
#
#                                       Pickup Centroid Longitude  \
# PU_H3           Trip Start Timestamp
# 8826641915fffff 2017-01-30                           -87.540936
#                 2017-01-31                           -87.540936
#                 2017-02-03                           -87.540936
#                 2017-03-07                           -87.540936
#                 2017-03-12                           -87.540936
# ...                                                         ...
# 88275936d5fffff 2017-11-26                           -87.813781
#                 2017-11-27                           -87.813781
#                 2017-11-28                           -87.813781
#                 2017-11-29                           -87.813781
#                 2017-11-30                           -87.813781
#
#                                       Dropoff Centroid Latitude  \
# PU_H3           Trip Start Timestamp
# 8826641915fffff 2017-01-30                            41.900070
#                 2017-01-31                            41.878866
#                 2017-02-03                            41.809018
#                 2017-03-07                            41.761578
#                 2017-03-12                            41.663671
# ...                                                         ...
# 88275936d5fffff 2017-11-26                            41.985015
#                 2017-11-27                            41.946511
#                 2017-11-28                            41.980264
#                 2017-11-29                            41.980264
#                 2017-11-30                            41.980264
#
#                                       Dropoff Centroid Longitude  PU_MONTH  \
# PU_H3           Trip Start Timestamp
# 8826641915fffff 2017-01-30                            -87.720918       1.0
#                 2017-01-31                            -87.625192       1.0
#                 2017-02-03                            -87.659167       2.0
#                 2017-03-07                            -87.572782       3.0
#                 2017-03-12                            -87.540936       3.0
# ...                                                          ...       ...
# 88275936d5fffff 2017-11-26                            -87.804532      11.0
#                 2017-11-27                            -87.806020      11.0
#                 2017-11-28                            -87.913625      11.0
#                 2017-11-29                            -87.913625      11.0
#                 2017-11-30                            -87.913625      11.0
#
#                                       PU_WEEKDAY  PU_HOUR  PU_HOUR_OF_WEEK
# PU_H3           Trip Start Timestamp
# 8826641915fffff 2017-01-30                   0.0     10.0             10.0
#                 2017-01-31                   1.0      8.0             32.0
#                 2017-02-03                   4.0     16.0            112.0
#                 2017-03-07                   1.0     17.0             41.0
#                 2017-03-12                   6.0     18.0            162.0
# ...                                          ...      ...              ...
# 88275936d5fffff 2017-11-26                   6.0      4.0            148.0
#                 2017-11-27                   0.0     21.0             21.0
#                 2017-11-28                   1.0      7.0             31.0
#                 2017-11-29                   2.0      7.0             55.0
#                 2017-11-30                   3.0     18.0             90.0
#
# [40933 rows x 19 columns]

# %%
#group by temporal and spacial resolutions
df_newer = df.groupby(['PU_H3', pd.Grouper(key="Trip Start Timestamp", freq="24H")]).median()
df_newer['count'] = df.groupby(['PU_H3', pd.Grouper(key="Trip Start Timestamp", freq="24H")]).size()
print("Dataframe after applying temporal and spacial specifications: ")
print("Shape: ",df_newer.shape)
print("Demand description for temporal/spatial units (e.g. 2017-01-01 09:00, 8826641915fffff): ")
print(df_newer['count'].describe())
# Out:
# Dataframe after applying temporal and spacial specifications:
# Shape:  (40933, 20)
# Demand description for temporal/spatial units (e.g. 2017-01-01 09:00, 8826641915fffff):
# count    40933.000000
# mean        98.205311
# std        282.818092
# min          1.000000
# 25%          2.000000
# 50%          7.000000
# 75%         46.000000
# max       3246.000000
# Name: count, dtype: float64

# %%
df_newer.shape
# Out:
# (21277, 20)

# %%
df_newer.dropna(inplace=True)

# %%
df_newer.shape
# Out:
# (21277, 20)

# %%
df_newer.head()
# Out:
#                                       Trip Seconds  Trip Miles  \
# PU_H3           Trip Start Timestamp
# 8826645219fffff 2017-01-01                  1320.0       12.25
#                 2017-01-02                  1560.0       12.10
#                 2017-01-03                  1560.0       12.10
#                 2017-01-04                  1470.0       12.10
#                 2017-01-05                  1512.0       12.30
#
#                                       Pickup Census Tract  \
# PU_H3           Trip Start Timestamp
# 8826645219fffff 2017-01-01                   1.703198e+10
#                 2017-01-02                   1.703198e+10
#                 2017-01-03                   1.703198e+10
#                 2017-01-04                   1.703198e+10
#                 2017-01-05                   1.703198e+10
#
#                                       Dropoff Census Tract  \
# PU_H3           Trip Start Timestamp
# 8826645219fffff 2017-01-01                    1.703108e+10
#                 2017-01-02                    1.703126e+10
#                 2017-01-03                    1.703128e+10
#                 2017-01-04                    1.703132e+10
#                 2017-01-05                    1.703132e+10
#
#                                       Pickup Community Area  \
# PU_H3           Trip Start Timestamp
# 8826645219fffff 2017-01-01                             56.0
#                 2017-01-02                             56.0
#                 2017-01-03                             56.0
#                 2017-01-04                             56.0
#                 2017-01-05                             56.0
#
#                                       Dropoff Community Area   Fare   Tips  \
# PU_H3           Trip Start Timestamp
# 8826645219fffff 2017-01-01                               8.0  32.75  6.750
#                 2017-01-02                               8.0  32.25  5.440
#                 2017-01-03                              28.0  32.00  5.925
#                 2017-01-04                              28.0  32.50  6.350
#                 2017-01-05                              28.0  32.75  6.190
#
#                                       Tolls  Extras  Trip Total  \
# PU_H3           Trip Start Timestamp
# 8826645219fffff 2017-01-01              0.0     4.0      43.050
#                 2017-01-02              0.0     4.0      42.500
#                 2017-01-03              0.0     4.0      42.275
#                 2017-01-04              0.0     4.0      42.200
#                 2017-01-05              0.0     4.0      42.900
#
#                                       Pickup Centroid Latitude  \
# PU_H3           Trip Start Timestamp
# 8826645219fffff 2017-01-01                           41.785999
#                 2017-01-02                           41.785999
#                 2017-01-03                           41.785999
#                 2017-01-04                           41.785999
#                 2017-01-05                           41.785999
#
#                                       Pickup Centroid Longitude  \
# PU_H3           Trip Start Timestamp
# 8826645219fffff 2017-01-01                           -87.750934
#                 2017-01-02                           -87.750934
#                 2017-01-03                           -87.750934
#                 2017-01-04                           -87.750934
#                 2017-01-05                           -87.750934
#
#                                       Dropoff Centroid Latitude  \
# PU_H3           Trip Start Timestamp
# 8826645219fffff 2017-01-01                            41.893216
#                 2017-01-02                            41.890922
#                 2017-01-03                            41.885300
#                 2017-01-04                            41.884987
#                 2017-01-05                            41.890922
#
#                                       Dropoff Centroid Longitude  PU_MONTH  \
# PU_H3           Trip Start Timestamp
# 8826645219fffff 2017-01-01                            -87.632109       1.0
#                 2017-01-02                            -87.632746       1.0
#                 2017-01-03                            -87.631864       1.0
#                 2017-01-04                            -87.631864       1.0
#                 2017-01-05                            -87.628990       1.0
#
#                                       PU_WEEKDAY  PU_HOUR  PU_HOUR_OF_WEEK  \
# PU_H3           Trip Start Timestamp
# 8826645219fffff 2017-01-01                   6.0     20.0            164.0
#                 2017-01-02                   0.0     17.0             17.0
#                 2017-01-03                   1.0     17.0             41.0
#                 2017-01-04                   2.0     18.0             66.0
#                 2017-01-05                   3.0     18.0             90.0
#
#                                       count
# PU_H3           Trip Start Timestamp
# 8826645219fffff 2017-01-01               84
#                 2017-01-02              119
#                 2017-01-03              138
#                 2017-01-04              129
#                 2017-01-05              157
