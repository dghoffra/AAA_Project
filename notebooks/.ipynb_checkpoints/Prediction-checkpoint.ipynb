# %%
#get notebook runtime
from timeit import default_timer as timer
start = timer()

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Characteristics

# %% [markdown]
# Let's recall the characteristics of our dataset:

# %%
#get notebook runtime
start = timer()

# %%
df = pd.read_parquet("../data/df_cleaned_18_06_2021.parquet")

# %%
df.shape
# Out:
# (4328648, 33)

# %%
df.head()
# Out:
#                                            Trip ID  \
# 10019694  0186acc0c8d50828e6dc5c9072ace58101e3e1b1
# 7792802   7d0830d9dbbd03a9e1b5d1d99cd41d99d7b8fb90
# 7493958   171ea5e4956fe55a58f9ec3be65238af8b79c4c2
# 5984763   a6da0037deae54685ba3a1a559ae6a33b9028bd9
# 4498023   58bc23a32b790e568d3c50bc38e5dd473cbc9fcf
#
#                                                     Taxi ID  \
# 10019694  9a38858dc2ace73a20f89a976154131a733daf1f11e8d6...
# 7792802   b4d59da1d7b8c002094752251906d9a3bcc6c7ea71a15f...
# 7493958   38c32bfda2f77c2a57f33a9e3fcf7edb8e996f59bc2254...
# 5984763   e2c349c7cbb608d552aa0b5814031943f13641ef9e50d8...
# 4498023   cbdd490649df25aa771979bed8930b199d27a990ccdb42...
#
#          Trip Start Timestamp  Trip End Timestamp  Trip Seconds  Trip Miles  \
# 10019694  2017-05-20 23:45:00 2017-05-20 23:45:00         360.0        1.30
# 7792802   2017-04-21 22:15:00 2017-04-21 22:15:00         300.0        0.40
# 7493958   2017-04-18 10:30:00 2017-04-18 10:45:00         379.0        1.00
# 5984763   2017-03-28 16:15:00 2017-03-28 16:15:00         317.0        0.96
# 4498023   2017-03-09 14:30:00 2017-03-09 14:30:00         360.0        1.00
#
#           Pickup Census Tract  Dropoff Census Tract  Pickup Community Area  \
# 10019694         1.703106e+10          1.703107e+10                    6.0
# 7792802          1.703108e+10          1.703108e+10                    8.0
# 7493958          1.703184e+10          1.703128e+10                   32.0
# 5984763          1.703108e+10          1.703108e+10                    8.0
# 4498023          1.703128e+10          1.703184e+10                   28.0
#
#           Dropoff Community Area  ...            PU_H3            DO_H3  \
# 10019694                     7.0  ...  872c2118bffffff  872c2118affffff
# 7792802                      8.0  ...  872c2119dffffff  872c2119dffffff
# 7493958                     28.0  ...  872c21191ffffff  872c2119cffffff
# 5984763                      8.0  ...  872c2119cffffff  872c2119cffffff
# 4498023                     32.0  ...  872c2119cffffff  872c21191ffffff
#
#           PU_MONTH_NAME  PU_WEEKDAY_NAME  PU_YEAR PU_MONTH PU_WEEKDAY  \
# 10019694            May         Saturday     2017        5          5
# 7792802           April           Friday     2017        4          4
# 7493958           April          Tuesday     2017        4          1
# 5984763           March          Tuesday     2017        3          1
# 4498023           March         Thursday     2017        3          3
#
#           PU_HOUR  PU_HOUR_OF_WEEK PU_FOUR_HOURLY
# 10019694       24              144            5/5
# 7792802        23              119            5/5
# 7493958        11               35            3/5
# 5984763        17               41            4/5
# 4498023        15               87            3/5
#
# [5 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# Trip ID                             0
# Taxi ID                          1477
# Trip Start Timestamp                0
# Trip End Timestamp                  0
# Trip Seconds                        0
# Trip Miles                          0
# Pickup Census Tract           1303676
# Dropoff Census Tract          1316214
# Pickup Community Area          309000
# Dropoff Community Area         392386
# Fare                                0
# Tips                                0
# Tolls                         1138339
# Extras                              0
# Trip Total                          0
# Payment Type                        0
# Company                             0
# Pickup Centroid Latitude       308810
# Pickup Centroid Longitude      308810
# Pickup Centroid Location       308810
# Dropoff Centroid Latitude      379954
# Dropoff Centroid Longitude     379954
# Dropoff Centroid  Location     379954
# PU_H3                          308810
# DO_H3                          379954
# PU_MONTH_NAME                       0
# PU_WEEKDAY_NAME                     0
# PU_YEAR                             0
# PU_MONTH                            0
# PU_WEEKDAY                          0
# PU_HOUR                             0
# PU_HOUR_OF_WEEK                     0
# PU_FOUR_HOURLY                      0
# dtype: int64

# %%
df_pairplot = df[:100]

# %%
#sns.pairplot(df_pairplot, hue='PU_H3')

# %% [markdown]
# Nun schauen wir uns explizit die Korrelationen der Variablen an. Wie ebenfalls im vorigen Plot zu observieren, sehen wir hier, dass die Variablen zum Teil stark positiv sowie negativ korrelieren.

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %% [markdown]
# Nun schauen wir uns die Verteilung unserer Zielvariablen taxi_demand (auf stündlicher basis) genauer an. Es ist zu erkennen, dass Samstags und Sonntags wesentlich häufiger früh am morgen das Taxi genutzt wird, als unter der Woche.

# %%
sns.displot(df,x='PU_HOUR', hue='PU_WEEKDAY', bins=24)

# %% [markdown]
# ## 4. SVM

# %% [markdown]
# ### Data Preparation for 4.1 SVM and 4.2 NN

# %% [markdown]
# Let's start with a reuseable function to get a dataframe of the selected temporal and spatial resolution. To obtain robust values for the predictors, we use the median.

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import h3

# %%
#TODO: Felix input for feature selection

# %%
def get_data(df, temp_resolution, spatial_resolution):
    
    #Set spacial resolution: Calculate new H3 based on specified resolution (alternative:make parent/child)
    '''df["PU_H3"] = df.apply(lambda x: h3.geo_to_h3(x["Pickup Centroid Latitude"],
                                                  x['Pickup Centroid Longitude'],
                                                  spatial_resolution),axis=1)
    #df["PU_H3"] = df["PU_H3"].replace("0",np.nan)'''
    PU_H3_dummies = pd.get_dummies(df.PU_H3)#get dummies for H3 for prediction (alternative: use H3 centroids)
    df = pd.concat([df, PU_H3_dummies], axis=1)
    
    #group by temporal and spacial resolution
    df_new = df.groupby(['PU_H3', pd.Grouper(key="Trip Start Timestamp", freq=temp_resolution)]).median()#create df based on temporal and spacial specifications
    df_new['count'] = df.groupby(['PU_H3', pd.Grouper(key="Trip Start Timestamp", freq=temp_resolution)]).size()#add demand for each unit of analysis; note that the frame is grouped by two features
    df_new.dropna(inplace=True)
    print("Dataframe after applying temporal and spacial specifications: ")#debug information
    print("Shape: ",df_new.shape)
    print("Demand description for temporal/spatial units (e.g. 2017-01-01 09:00, 8826641915fffff): ")
    #print(df_new['count'].describe())
    
    #select target and predictors
    y = df_new['count']
    X = df_new.drop('count', axis=1)
    print('Debug Information')
    print('-------------------------------')
    print("Shape Featureset/Target: ", X.shape, y.shape)
    print(X.iloc[0])
    
    #split data
    x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.6, random_state=38)
    
    #scale data
    scaler = StandardScaler()
    scaler.fit(x_train) #fit scaler
    X_train_scaled = scaler.transform(x_train) #apply to both, train and test set
    X_test_scaled = scaler.transform(x_test)
    print("Shape after scaling trainingset: ", X_train_scaled.shape, y_train.shape)
    print("Shape after scaling testset: ", X_test_scaled.shape, y_test.shape)
    
    #select best features
    selector = SelectKBest(f_classif, k=40)
    selector.fit(X_train_scaled, y_train)
    cols = selector.get_support(indices=True)#get selected columns
    X_train_new = X_train_scaled[:,cols]#apply to train&test set
    X_test_new = X_test_scaled[:,cols]
    print("X_Train:", X_train_new.shape, "X_Test:", X_test_new.shape)
    
    return X_train_new, X_test_new, y_train, y_test

# %% [markdown]
# ### 4.1.1 SVM Prediction

# %% [markdown]
# First, we define a training method and to use it for training our models. Consequently, we will start with simple models and improve them for better performance.

# %%
#function to train and evaluate our models later on
import sklearn.metrics as metrics
import numpy as np

def train(model, model_name, x_train, x_test, y_train, y_test, element):
    
    print()
    print(model_name, element) # Printing model name
    print('-------------------------------')
    model.fit(x_train,y_train) # fitting the defined model
    pred = model.predict(x_test) # predicting our data

    acc = metrics.r2_score(y_test, pred) #Checking R2_Score
    print('R2_Score',acc)

    met = np.sqrt(metrics.mean_squared_error(y_test, pred)) #Calculating RMSE
    print('RMSE : ', met) 

    var = (metrics.explained_variance_score(y_test, pred)) #Calculating explained_variance_score
    print('Explained_Variance : ', var)

    error = (metrics.max_error(y_test, pred)) #Calculating Max_Error
    print('Max_Error : ', error)
    
    err = metrics.mean_absolute_error(y_test, pred) #Calculating mean_absolute_error
    print("Mean Absolute Error", err)
    print()
    print()
    
    return model_name + '($R^2={:.3f}$)'.format(acc), np.array(y_test), pred

# %%
#select data to start with, we use a daily level for our inital modeling 

X_train_new, X_test_new, y_train, y_test = get_data(df, temp_resolution="24H", spatial_resolution = 8)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-c7092b5b1499> in <module>
#       1 #select data to start with, we use a daily level for our inital modeling
#       2
# ----> 3 X_train_new, X_test_new, y_train, y_test = get_data(df, temp_resolution="24H", spatial_resolution = 8)
#
# <ipython-input-93-a714402d4a49> in get_data(df, temp_resolution, spatial_resolution)
#      20     #group by temporal and spacial resolution
#      21     df_new = df.groupby(['PU_H3', pd.Grouper(key="Trip Start Timestamp", freq=temp_resolution)]).median()#create df based on temporal and spacial specifications
# ---> 22     df_new['count'] = df.groupby(['PU_H3', pd.Grouper(key="Trip Start Timestamp", freq=temp_resolution)]).size()#add demand for each unit of analysis; note that the frame is grouped by two features
#      23     df_new.dropna(inplace=True)
#      24     print("Dataframe after applying temporal and spacial specifications: ")#debug information
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6725             squeeze=squeeze,
#    6726             observed=observed,
# -> 6727             dropna=dropna,
#    6728         )
#    6729
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     566                 observed=observed,
#     567                 mutated=self.mutated,
# --> 568                 dropna=self.dropna,
#     569             )
#     570
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     837                 dropna=dropna,
#     838             )
# --> 839             if not isinstance(gpr, Grouping)
#     840             else gpr
#     841         )
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis, dropna)
#     492             # check again as we have by this point converted these
#     493             # to an actual value (rather than a pd.Grouper)
# --> 494             _, grouper, _ = self.grouper._get_grouper(self.obj, validate=False)
#     495             if self.name is None:
#     496                 self.name = grouper.result_index.name
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/resample.py in _get_grouper(self, obj, validate)
#    1482     def _get_grouper(self, obj, validate: bool = True):
#    1483         # create the resampler and return our binner
# -> 1484         r = self._get_resampler(obj)
#    1485         r._set_binner()
#    1486         return r.binner, r.grouper, r.obj
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
#    1464
#    1465         """
# -> 1466         self._set_grouper(obj)
#    1467
#    1468         ax = self.ax
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in _set_grouper(self, obj, sort)
#     386             indexer = self.indexer = ax.argsort(kind="mergesort")
#     387             ax = ax.take(indexer)
# --> 388             obj = obj.take(indexer, axis=self.axis)
#     389
#     390         self.obj = obj
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3585
#    3586         new_data = self._mgr.take(
# -> 3587             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3588         )
#    3589         return self._constructor(new_data).__finalize__(self, method="take")
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1473         new_labels = self.axes[axis].take(indexer)
#    1474         return self.reindex_indexer(
# -> 1475             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1476         )
#    1477
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#    1317                     ),
#    1318                 )
# -> 1319                 for blk in self.blocks
#    1320             ]
#    1321
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1317                     ),
#    1318                 )
# -> 1319                 for blk in self.blocks
#    1320             ]
#    1321
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1403
#    1404         new_values = algos.take_nd(
# -> 1405             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1406         )
#    1407
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1757         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#    1758     )
# -> 1759     func(arr, indexer, out, fill_value)
#    1760
#    1761     if flip_order:
#
# KeyboardInterrupt:

# %%
#Start without a Kernel
results=[] #save results-tuple for visualization
model_svr = SVR()
results.append(train(model_svr, "SVR", X_train_new, X_test_new,
                     y_train, y_test, "24H" ))

# %%
#Make more complex
model_svr2 = SVR(kernel='linear')
results.append(train(model_svr2, "SVR_Linear", X_train_new, X_test_new,
                     y_train, y_test, "24H"))

# %%
#TODO Hyperparameter Tuning

# %% [markdown]
# ### 4.1.2 Model Evaluation (Visually)

# %% [markdown]
# In this section, we will examine the performance of our models more closely. For this, we will look at the visual characteristics of our predictions.

# %%
# Bessere Visualisierung einbauen

# %%
#Create a plot comparing multiple learners
def plot(results):
    # Using subplots to display the results on the same X axis
    fig, plts = plt.subplots(nrows=len(results), figsize=(8, 8))
    fig.canvas.set_window_title('Predicting Chicago')

    # Show each element in the plots returned from plt.subplots()
    for subplot, (title, y, y_pred) in zip(plts, results):
        # Configure each subplot to have no tick marks
        # (these are meaningless for the sample dataset)
        subplot.set_xticklabels(())
        subplot.set_yticklabels(())

        # Label the vertical axis
        subplot.set_ylabel('Taxi Demand')
        subplot.set_xlabel('Time')

        # Set the title for the subplot
        subplot.set_title(title)

        # Plot the actual data and the prediction
        subplot.plot(y, 'b', label='actual')
        subplot.plot(y_pred, 'r', label='predicted')
        
        # Shade the area between the predicted and the actual values
        subplot.fill_between(
            # Generate X values [0, 1, 2, ..., len(y)-2, len(y)-1]
            np.arange(0, len(y), 1),
            y,
            y_pred,
            color='r',
            alpha=0.2
        )

        # Mark the extent of the training data
        subplot.axvline(len(y) // 2, linestyle='--', color='0', alpha=0.2)

        # Include a legend in each subplot
        subplot.legend()

    # Let matplotlib handle the subplot layout
    fig.tight_layout()
    plt.show()
    plt.savefig('plot.png')
    plt.close()

# %%
plot(results)

# %% [markdown]
# ### 4.1.3 Variation of Temporal and Spatial Resolution

# %% [markdown]
# In this section, we aim to explore the performance of our best model based on a variation of termporal and spatial resolutions.

# %%
#TODO: Add Spatial Resolution

# %%
#TODO: Plot RMSE based on specifications

# %%
#generate datasets - temporal dimension
temporal_resolution_levels = ['24H', '6H', '2H', '1H']

results = []

for element in temporal_resolution_levels:
    model = SVR(kernel='linear')
    X_train_new, X_test_new, y_train, y_test = get_data(df, element)
    results.append(train(model, "SVR_Linear", X_train_new, X_test_new,
                         y_train, y_test, element))

end = timer()
print()
print("Total Notebook Runtime (s): ", end - start)
# Out:
# Dataframe after applying temporal and spacial specifications:
# Shape:  (4963, 20)
# Demand description for temporal/spatial units (e.g. 2017-01-01 09:00, 8826641915fffff):
# count    4963.000000
# mean      801.890792
# std      1443.735060
# min         1.000000
# 25%        99.000000
# 50%       203.000000
# 75%       657.000000
# max      8129.000000
# Name: count, dtype: float64
# Int64Index([10019694,  7792802,  7493958,  5984763,  4498023, 23045760,
#             10066611,  8579393, 22651869,  4405282,
#             ...
#             11083039,  3959336, 19027410,  4501119,  6037775, 22209691,
#              1557193,  5281251, 13237511, 13075114],
#            dtype='int64', length=4328648)
# Debug Information
# -------------------------------
# Shape Featureset/Target:  (4963, 19) (4963,)
# Trip Seconds                  4.800000e+02
# Trip Miles                    1.900000e+00
# Pickup Census Tract           1.703183e+10
# Dropoff Census Tract          1.703103e+10
# Pickup Community Area         1.000000e+00
# Dropoff Community Area        3.000000e+00
# Fare                          8.250000e+00
# Tips                          0.000000e+00
# Tolls                         0.000000e+00
# Extras                        0.000000e+00
# Trip Total                    9.000000e+00
# Pickup Centroid Latitude      4.200170e+01
# Pickup Centroid Longitude    -8.767357e+01
# Dropoff Centroid Latitude     4.198796e+01
# Dropoff Centroid Longitude   -8.767145e+01
# PU_MONTH                      1.000000e+00
# PU_WEEKDAY                    6.000000e+00
# PU_HOUR                       7.000000e+00
# PU_HOUR_OF_WEEK               1.510000e+02
# Name: (872c21002ffffff, 2017-01-01 00:00:00), dtype: float64
# Shape after scaling trainingset:  (2977, 19) (2977,)
# Shape after scaling testset:  (1986, 19) (1986,)
# X_Train: (2977, 10) X_Test: (1986, 10)
#
# SVR_Linear 24H
# -------------------------------
# R2_Score -0.11957911279185662
# RMSE :  1586.7995358121805
# Explained_Variance :  0.03752153916569867
# Max_Error :  7135.620287738925
# Mean Absolute Error 718.2083836844506
#
#
# Dataframe after applying temporal and spacial specifications:
# Shape:  (15011, 20)
# Demand description for temporal/spatial units (e.g. 2017-01-01 09:00, 8826641915fffff):
# count    15011.000000
# mean       261.084138
# std        460.958278
# min          1.000000
# 25%         36.000000
# 50%         76.000000
# 75%        205.000000
# max       3112.000000
# Name: count, dtype: float64
# Int64Index([10019694,  7792802,  7493958,  5984763,  4498023, 23045760,
#             10066611,  8579393, 22651869,  4405282,
#             ...
#             11083039,  3959336, 19027410,  4501119,  6037775, 22209691,
#              1557193,  5281251, 13237511, 13075114],
#            dtype='int64', length=4328648)
# Debug Information
# -------------------------------
# Shape Featureset/Target:  (15011, 19) (15011,)
# Trip Seconds                  4.355000e+02
# Trip Miles                    1.695000e+00
# Pickup Census Tract           1.703183e+10
# Dropoff Census Tract          1.703103e+10
# Pickup Community Area         1.000000e+00
# Dropoff Community Area        3.000000e+00
# Fare                          8.000000e+00
# Tips                          0.000000e+00
# Tolls                         0.000000e+00
# Extras                        0.000000e+00
# Trip Total                    9.000000e+00
# Pickup Centroid Latitude      4.200566e+01
# Pickup Centroid Longitude    -8.767187e+01
# Dropoff Centroid Latitude     4.198671e+01
# Dropoff Centroid Longitude   -8.767017e+01
# PU_MONTH                      1.000000e+00
# PU_WEEKDAY                    6.000000e+00
# PU_HOUR                       4.000000e+00
# PU_HOUR_OF_WEEK               1.480000e+02
# Name: (872c21002ffffff, 2017-01-01 00:00:00), dtype: float64
# Shape after scaling trainingset:  (9006, 19) (9006,)
# Shape after scaling testset:  (6005, 19) (6005,)
# X_Train: (9006, 10) X_Test: (6005, 10)
#
# SVR_Linear 6H
# -------------------------------
# R2_Score -0.133511185502603
# RMSE :  491.29110728191586
# Explained_Variance :  0.014265783138768917
# Max_Error :  3004.952567410512
# Mean Absolute Error 217.85662271598468
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-a1b629a535a9> in <module>
#       6 for element in temporal_resolution_levels:
#       7     model = SVR(kernel='linear')
# ----> 8     X_train_new, X_test_new, y_train, y_test = get_data(df, element)
#       9     results.append(train(model, "SVR_Linear", X_train_new, X_test_new,
#      10                          y_train, y_test, element))
#
# <ipython-input-16-67bdb0723c55> in get_data(df, temp_resolution)
#      12
#      13     df_new = df.groupby(['PU_H3', pd.Grouper(key="Trip Start Timestamp", freq=temp_resolution)]).median()#create df based on temporal and spacial specifications
# ---> 14     df_new['count'] = df.groupby(['PU_H3', pd.Grouper(key="Trip Start Timestamp", freq=temp_resolution)]).size()#add demand for each unit of analysis; note that the frame is grouped by two features
#      15     df_new.dropna(inplace=True)
#      16     print("Dataframe after applying temporal and spacial specifications: ")#debug information
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6725             squeeze=squeeze,
#    6726             observed=observed,
# -> 6727             dropna=dropna,
#    6728         )
#    6729
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     566                 observed=observed,
#     567                 mutated=self.mutated,
# --> 568                 dropna=self.dropna,
#     569             )
#     570
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     837                 dropna=dropna,
#     838             )
# --> 839             if not isinstance(gpr, Grouping)
#     840             else gpr
#     841         )
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis, dropna)
#     492             # check again as we have by this point converted these
#     493             # to an actual value (rather than a pd.Grouper)
# --> 494             _, grouper, _ = self.grouper._get_grouper(self.obj, validate=False)
#     495             if self.name is None:
#     496                 self.name = grouper.result_index.name
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/resample.py in _get_grouper(self, obj, validate)
#    1482     def _get_grouper(self, obj, validate: bool = True):
#    1483         # create the resampler and return our binner
# -> 1484         r = self._get_resampler(obj)
#    1485         r._set_binner()
#    1486         return r.binner, r.grouper, r.obj
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
#    1468         ax = self.ax
#    1469         if isinstance(ax, DatetimeIndex):
# -> 1470             return DatetimeIndexResampler(obj, groupby=self, kind=kind, axis=self.axis)
#    1471         elif isinstance(ax, PeriodIndex) or kind == "period":
#    1472             return PeriodIndexResampler(obj, groupby=self, kind=kind, axis=self.axis)
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/resample.py in __init__(self, obj, groupby, axis, kind, **kwargs)
#     101
#     102         if self.groupby is not None:
# --> 103             self.groupby._set_grouper(self._convert_obj(obj), sort=True)
#     104
#     105     def __str__(self) -> str:
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in _set_grouper(self, obj, sort)
#     386             indexer = self.indexer = ax.argsort(kind="mergesort")
#     387             ax = ax.take(indexer)
# --> 388             obj = obj.take(indexer, axis=self.axis)
#     389
#     390         self.obj = obj
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3585
#    3586         new_data = self._mgr.take(
# -> 3587             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3588         )
#    3589         return self._constructor(new_data).__finalize__(self, method="take")
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1473         new_labels = self.axes[axis].take(indexer)
#    1474         return self.reindex_indexer(
# -> 1475             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1476         )
#    1477
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#    1317                     ),
#    1318                 )
# -> 1319                 for blk in self.blocks
#    1320             ]
#    1321
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1317                     ),
#    1318                 )
# -> 1319                 for blk in self.blocks
#    1320             ]
#    1321
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1403
#    1404         new_values = algos.take_nd(
# -> 1405             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1406         )
#    1407
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1757         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#    1758     )
# -> 1759     func(arr, indexer, out, fill_value)
#    1760
#    1761     if flip_order:
#
# KeyboardInterrupt:

# %%
#77community areas
#866 census tracts (population between 0 - 10000)
#resolution 0-15, with 0 beeing the

# %%
'''import h3

resolution = 1
#calculate new H3 based on specified resolution

df["PU_H3"] = df.apply(lambda x: h3.geo_to_h3(x["Pickup Centroid Latitude"], x['Pickup Centroid Longitude'],8),axis=1)
df["PU_H3"] = df["PU_H3"].replace("0",np.nan)
'''
