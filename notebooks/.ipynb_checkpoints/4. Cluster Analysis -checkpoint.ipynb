# %%
#########################steps belowonly for testing reason ###############################
# Sampling function
def sampleFile(sample_size,df):
    df_new = df.sample(frac = (sample_size/100))
    return df_new

df = sampleFile(1,df)

# %%
#importing libraries 
import pandas as pd 
import numpy as np
import geopandas as gpd
from haversine import haversine, Unit
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from folium import folium, Marker
import warnings
warnings.filterwarnings("ignore")

#show all columns 
pd.set_option('display.max_columns', None)

# %%
#read in cleaned dataframe
df = pd.read_parquet("../data/df_cleaned_18_06_2021.parquet")

# %%
features
# Out:
#           duration_in_minutes                    Company  HOUR
# 10019694                 6.00  Dispatch Taxi Affiliation    24
# 7792802                  5.00  Dispatch Taxi Affiliation    23
# 7493958                  6.32                  Flash Cab    11
# 5984763                  5.28  Nova Taxi Affiliation Llc    17
# 4498023                  6.00   Northwest Management LLC    15
# ...                       ...                        ...   ...
# 22209691                 7.00                 Globe Taxi    22
# 1557193                 12.38  Nova Taxi Affiliation Llc    17
# 5281251                  9.00               City Service    24
# 13237511                 6.18                 Yellow Cab    16
# 13075114                39.00           Medallion Leasin    20
#
# [4328648 rows x 3 columns]

# %% [markdown]
# # Clustering

# %%
#import
#pip install fuzzy-c-means
from matplotlib.colors import ListedColormap, BoundaryNorm
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import numpy as np
from fcmeans import FCM
from matplotlib import pyplot as plt
from sklearn.mixture import GaussianMixture

# %% [markdown]
# ### 1. Data preparation
# Now we prepare our data for the clustering and we define needed methods.

# %%
#function for adding wanted columns
def adding_column(df,keyword = None):
    if keyword == "distance city":
        df['PU_DISTANCE_CITY'] = df.apply(
        lambda row: haversine((row["Pickup Centroid Latitude"], row["Pickup Centroid Longitude"]), (41.85003, -87.65005), Unit.KILOMETERS), axis=1)
        df['DO_DISTANCE_CITY'] = df.apply(
        lambda row: haversine((row["Dropoff Centroid Latitude"], row["Dropoff Centroid Longitude"]), (41.85003, -87.65005), Unit.KILOMETERS), axis=1)
        return df
    if keyword == "dur":
        df["DURATION_IN_MINUTES"] = df["Trip Seconds"]/60
        df['DURATION_IN_MINUTES'] = df['DURATION_IN_MINUTES'].round(2)
        return df
    else: 
        print("No option selected!")

# %%
df = adding_column(df,"dur")
cluster_df = df[['DURATION_IN_MINUTES',"PU_HOUR"]].copy()
cluster_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### 2. Loss function method
# Now we build a loss functions for our soft and hard clustering methods.
# We created one method for this purpose:

# %%
#function for getting the best clustering value for hard and soft clustering functions 

########################################################
### !!!!!!  hard loss functions not implemented yet ####
########################################################
def loss_clustering(df, method = None, clustering_type = None):
    
    if clustering_type == "H":
        #scale data
        scaler = StandardScaler()
        scaler.fit(df)
        X_scaled = scaler.transform(df)
        X_scaled_df = pd.DataFrame(X_scaled, columns=df.columns, index=df.index)

        #create clustering and losses for 1 to 20 clusters
        clusters = []
        losses = []
        for i in range(1, 20):

            if (method == "KMEANS"):
                model = KMeans(n_clusters=i+1)
                model.fit(X_scaled)
                clusters.append(i+1)
                losses.append(model.inertia_)
                out = 'Clusterings completed: '+str(i+1)
                print(out, end='\r')
            else: 
                raise Exception('ERROR\nThe following hard clustering are supported:\n- KMEANS\nPlease choose one the supported methods.') 

        #plot loss for each number of clusters
        print("Showing the loss for hard clustering methods")
        plt.figure(figsize=(10,5))
        plt.xlabel('Number of Clusters')
        plt.ylabel('Loss')
        plt.title('Loss by Number of Clusters')
        plt.plot(clusters, losses)
    elif clustering_type == "S":
        print("currently not implemented.")
    else:
        raise Exception('Currently only soft (S) and hard (H) clustering functions implemented')

# %% [markdown]
# # Following two steps are testing of loss creating for soft models - not finished!

# %%
##TEST OF LOSS FUNCTION BASED ON partition coefficient and partition entropy coefficient 
n_clusters_list = [1,2,3]
models = list()
for n_clusters in n_clusters_list:
    fcm = FCM(n_clusters)
    fcm.fit(cluster_df)
    models.append(fcm)

# %%
num_clusters = len(n_clusters_list)
rows = int(np.ceil(np.sqrt(num_clusters)))
cols = int(np.ceil(num_clusters / rows))
f, axes = plt.subplots(rows, cols, figsize=(11,16))
for n_clusters, model, axe in zip(n_clusters_list, models, axes.ravel()):
    # get validation metrics
    pc = model.partition_coefficient
    pec = model.partition_entropy_coefficient
    
    fcm_centers = model.centers
    fcm_labels = model.predict(X)
    # plot result
    axe.scatter(X[:,0], X[:,1], c=fcm_labels, alpha=.1)
    axe.scatter(fcm_centers[:,0], fcm_centers[:,1], marker="+", s=500, c='black')
    axe.set_title(f'n_clusters = {n_clusters}, PC = {pc:.3f}, PEC = {pec:.3f}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-145-f9161efc9bed> in <module>
#       5 for n_clusters, model, axe in zip(n_clusters_list, models, axes.ravel()):
#       6     # get validation metrics
# ----> 7     pc = model.partition_coefficient
#       8     pec = model.partition_entropy_coefficient
#       9
#
# AttributeError: 'FCM' object has no attribute 'partition_coefficient'

# %% [markdown]
# ### 3. Clustering methods
# Now we build clustering methods. The first method is a 2d plotting function.

# %%
#clustering method for all clustering methods
#currently working: FUZZYC (soft), KMEANS(hard)
def clustering_2d(ctype,amntClusters, df, xAxis, yAxis, name):
    
    #check if KMEANS
    if ctype == "KMEANS":
        km = KMeans(amntClusters)
        km.fit(df)
        km.predict(df)
        labels = km.labels_
        df['Cluster'] = labels 
    #check if FUZZYC
    elif ctype == "FUZZY C":
        fcm = FCM(amntClusters)
        fcm.fit(df)
        fcm.predict(df)
        labels = fcm.predict(df)
        df['Cluster'] = labels
    else: 
        raise Exception("ERROR\nSupported clustering methods:\n- KMEANS\n- FUZZY C\nPlease try again. ")
    
    #counting points in cluster
    clusteringData = pd.DataFrame(columns={'x', 'y', 'count', '%'}, index=np.arange(0, amntClusters))
    for i in range(0, amntClusters):
        #get point in middle of cluster i
        clusteringData.loc[i, 'x']=df[df['Cluster']==i][xAxis].mean()
        clusteringData.loc[i, 'y']=df[df['Cluster']==i][yAxis].mean()
        #get count of points in cluster i and percentage of points in cluster i compared to all clusters
        clusteringData.loc[i, 'count']=df[df['Cluster']==i][xAxis].count()
        clusteringData.loc[i, '%']=int(df[df['Cluster']==i][xAxis].count()/len(df)*100)
    
    #plotting
    plt.figure(1, figsize=(20,10))
    plt.scatter(df[xAxis], df[yAxis], c=labels.astype(np.float), edgecolor='none', s=100)
    #number of points in cluster
    for i in range(0, amntClusters):
        plt.annotate(str(clusteringData.loc[i, 'count'])+'('+str(clusteringData.loc[i, '%'])+'%)',
                     (clusteringData.loc[i, 'x'], clusteringData.loc[i, 'y']), fontsize=20, fontweight='bold')
    plt.xlabel(xAxis)
    plt.ylabel(yAxis)
    plt.title(ctype.title()+' for '+name)

# %% [markdown]
# ### 4. Hard clustering
# First we check the best loss for our hard clustering functions for the duration in minutes and the start hour:

# %%
#get optim
loss_clustering(cluster_df,"KMEANS","H")
# Out:
# Showing the loss for hard clustering methods

# %% [markdown]
# Let's choose 5 as the number of clusters, since the curve does not change much anymore. Based on n_clusters = 5, we execute the KMEANS algorithm for

# %%
#optional step - removes all values which are bigger than 65 - the clusters looks better in this case 
cluster_df_red = cluster_df[(cluster_df['DURATION_IN_MINUTES'] <= 45)]

# %%
#KMEANS clustering plot for duration in minutes & PU_HOUR
clustering_2d("KMEANS",5, cluster_df_red, "DURATION_IN_MINUTES", "PU_HOUR", "the duration and the hour")

# %% [markdown]
# ### 5. Soft clustering
# Now we also analyze our duration in minutes and our starting hours wit soft clustring methods. Thereby we first use the FUZZY C Clustering method. First we determine the loss:

# %%
###########################################
###!!! LOSS CURRENTLY NOT IMPLEMENTED !!!###
###########################################

loss_clustering(cluster_df,"KMEANS","S")
# Out:
# currently not implemented.

# %%
#FUZZY-C clustering plot for duration in minutes & PU_HOUR
clustering_2d("FUZZY C",5, cluster_df_red, "DURATION_IN_MINUTES", "PU_HOUR", "the duration and the hour")
